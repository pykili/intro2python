# %% [markdown]
# ### *Файлы*
#
# ***Порядок действий***:
# 1. открыть файл
# 2. выполнить какие-то действия
# 3. закрыть файл (!!)
#
# Все постоянно забывают о последнем пункте, но так делать низя!

# %% [markdown]
# 1. ***Как открыть файл?***
#
# При помощи функции `open()`:
#
# ```python
# open('path/to/file.txt', 'mode', encoding='encoding_of_file')
# ```
#
# У нее есть три аргумента:
# 1. путь к файлу (тут мы уже все обсудили)
# 2. режим открытия:
#
# | Режим | Обозначение                                                     |
# |-------|-----------------------------------------------------------------|
# | `'r'` | открытие на чтение (значение по умолчанию)                      |
# | `'w'` | открытие на запись:<br> - содержимое файла **удаляется**, если файл существует,<br> - создается новый, если файла не существует               |
# | `'x'` | открытие на запись, если файла не существует, иначе исключение  |
# | `'a'` | открытие на дозапись, информация добавляется в конец файла      |
# | `'b'` | открытие в двоичном режиме                                      |
#
# 3. кодировка (чаще всего `encoding='utf-8'`, но иногда случается...)

# %%
f = open("input.txt", "r", encoding="utf-8")  # открыть файл
f.readlines()  # прочитать все строчки, заметьте, что они с \n
# Out:
# ['Я в своем познании настолько преисполнился, что я как будто бы уже\n',
#  'сто триллионов миллиардов лет проживаю на триллионах и\n',
#  'триллионах таких же планет, как эта Земля, мне этот мир абсолютно\n',
#  'понятен, и я здесь ищу только одного - покоя, умиротворения и\n',
#  'вот этой гармонии, от слияния с бесконечно вечным, от созерцания\n',
#  'великого фрактального подобия и от вот этого замечательного всеединства\n',
#  'существа, бесконечно вечного, куда ни посмотри, хоть вглубь - бесконечно\n',
#  'малое, хоть ввысь - бесконечное большое, понимаешь? А ты мне опять со\n',
#  'своим вот этим, иди суетись дальше, это твоё распределение, это\n',
#  'твой путь и твой горизонт познания и ощущения твоей природы, он\n',
#  'несоизмеримо мелок по сравнению с моим, понимаешь? Я как будто бы уже\n',
#  'давно глубокий старец, бессмертный, ну или там уже почти бессмертный,\n',
#  'который на этой планете от её самого зарождения, ещё когда только Солнце\n',
#  'только-только сформировалось как звезда, и вот это газопылевое облако,\n',
#  'вот, после взрыва, Солнца, когда оно вспыхнуло, как звезда, начало\n',
#  'формировать вот эти коацерваты, планеты, понимаешь, я на этой Земле уже\n',
#  'как будто почти пять миллиардов лет живу и знаю её вдоль и поперёк\n',
#  'этот весь мир, а ты мне какие-то... мне не важно на твои тачки, на твои\n',
#  'яхты, на твои квартиры, там, на твоё благо.']

# %%
print(f.readlines())  # второй раз прочитать файл не получится
# Out:
# []

# %%
# если оч нужно, то можно сделать так:
f.seek(0)  # это вернет указатель в начало файла и его снова можно будет читать сначала

f.read()
# Out:
# 'Я в своем познании настолько преисполнился, что я как будто бы уже\nсто триллионов миллиардов лет проживаю на триллионах и\nтриллионах таких же планет, как эта Земля, мне этот мир абсолютно\nпонятен, и я здесь ищу только одного - покоя, умиротворения и\nвот этой гармонии, от слияния с бесконечно вечным, от созерцания\nвеликого фрактального подобия и от вот этого замечательного всеединства\nсущества, бесконечно вечного, куда ни посмотри, хоть вглубь - бесконечно\nмалое, хоть ввысь - бесконечное большое, понимаешь? А ты мне опять со\nсвоим вот этим, иди суетись дальше, это твоё распределение, это\nтвой путь и твой горизонт познания и ощущения твоей природы, он\nнесоизмеримо мелок по сравнению с моим, понимаешь? Я как будто бы уже\nдавно глубокий старец, бессмертный, ну или там уже почти бессмертный,\nкоторый на этой планете от её самого зарождения, ещё когда только Солнце\nтолько-только сформировалось как звезда, и вот это газопылевое облако,\nвот, после взрыва, Солнца, когда оно вспыхнуло, как звезда, начало\nформировать вот эти коацерваты, планеты, понимаешь, я на этой Земле уже\nкак будто почти пять миллиардов лет живу и знаю её вдоль и поперёк\nэтот весь мир, а ты мне какие-то... мне не важно на твои тачки, на твои\nяхты, на твои квартиры, там, на твоё благо.'

# %%
f = open("input.txt", "r")  # открыть файл
f.read().split('\n')  # прочитать весь файл одной строкой
# Out:
# ['Я в своем познании настолько преисполнился, что я как будто бы уже',
#  'сто триллионов миллиардов лет проживаю на триллионах и',
#  'триллионах таких же планет, как эта Земля, мне этот мир абсолютно',
#  'понятен, и я здесь ищу только одного - покоя, умиротворения и',
#  'вот этой гармонии, от слияния с бесконечно вечным, от созерцания',
#  'великого фрактального подобия и от вот этого замечательного всеединства',
#  'существа, бесконечно вечного, куда ни посмотри, хоть вглубь - бесконечно',
#  'малое, хоть ввысь - бесконечное большое, понимаешь? А ты мне опять со',
#  'своим вот этим, иди суетись дальше, это твоё распределение, это',
#  'твой путь и твой горизонт познания и ощущения твоей природы, он',
#  'несоизмеримо мелок по сравнению с моим, понимаешь? Я как будто бы уже',
#  'давно глубокий старец, бессмертный, ну или там уже почти бессмертный,',
#  'который на этой планете от её самого зарождения, ещё когда только Солнце',
#  'только-только сформировалось как звезда, и вот это газопылевое облако,',
#  'вот, после взрыва, Солнца, когда оно вспыхнуло, как звезда, начало',
#  'формировать вот эти коацерваты, планеты, понимаешь, я на этой Земле уже',
#  'как будто почти пять миллиардов лет живу и знаю её вдоль и поперёк',
#  'этот весь мир, а ты мне какие-то... мне не важно на твои тачки, на твои',
#  'яхты, на твои квартиры, там, на твоё благо.']

# %%
f.close()  # закрыть файл после окончания работы с ним

# %%
fin = open("input.txt", "r")
1/0
fin.close()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 fin = open("input.txt", "r")
# ----> 2 1/0
#       3 fin.close()
#
# ZeroDivisionError: division by zero

# %%
with open("input.txt", "r") as f:  # чтобы руками не закрывать файл, можно писать вот так
    while line := f.readline().strip():  # читать файл построчно, пока строчки есть
        # strip тут на всякий случай, можно и не писать
        print(line)  # если не написать strip, то будет лишняя пустая строка
        # так как readline читает и пробельные символы тоже
# Out:
# Я в своем познании настолько преисполнился, что я как будто бы уже
# сто триллионов миллиардов лет проживаю на триллионах и
# триллионах таких же планет, как эта Земля, мне этот мир абсолютно
# понятен, и я здесь ищу только одного - покоя, умиротворения и
# вот этой гармонии, от слияния с бесконечно вечным, от созерцания
# великого фрактального подобия и от вот этого замечательного всеединства
# существа, бесконечно вечного, куда ни посмотри, хоть вглубь - бесконечно
# малое, хоть ввысь - бесконечное большое, понимаешь? А ты мне опять со
# своим вот этим, иди суетись дальше, это твоё распределение, это
# твой путь и твой горизонт познания и ощущения твоей природы, он
# несоизмеримо мелок по сравнению с моим, понимаешь? Я как будто бы уже
# давно глубокий старец, бессмертный, ну или там уже почти бессмертный,
# который на этой планете от её самого зарождения, ещё когда только Солнце
# только-только сформировалось как звезда, и вот это газопылевое облако,
# вот, после взрыва, Солнца, когда оно вспыхнуло, как звезда, начало
# формировать вот эти коацерваты, планеты, понимаешь, я на этой Земле уже
# как будто почти пять миллиардов лет живу и знаю её вдоль и поперёк
# этот весь мир, а ты мне какие-то... мне не важно на твои тачки, на твои
# яхты, на твои квартиры, там, на твоё благо.

# %%
with open("input.txt", "r") as f:
    for i, line in enumerate(f, start=1):
        if line.strip():
            print(f"line number {i}: {line.strip()}")
# Out:
# line number 1: Я в своем познании настолько преисполнился, что я как будто бы уже
# line number 2: сто триллионов миллиардов лет проживаю на триллионах и
# line number 3: триллионах таких же планет, как эта Земля, мне этот мир абсолютно
# line number 4: понятен, и я здесь ищу только одного - покоя, умиротворения и
# line number 5: вот этой гармонии, от слияния с бесконечно вечным, от созерцания
# line number 6: великого фрактального подобия и от вот этого замечательного всеединства
# line number 7: существа, бесконечно вечного, куда ни посмотри, хоть вглубь - бесконечно
# line number 8: малое, хоть ввысь - бесконечное большое, понимаешь? А ты мне опять со
# line number 9: своим вот этим, иди суетись дальше, это твоё распределение, это
# line number 10: твой путь и твой горизонт познания и ощущения твоей природы, он
# line number 11: несоизмеримо мелок по сравнению с моим, понимаешь? Я как будто бы уже
# line number 12: давно глубокий старец, бессмертный, ну или там уже почти бессмертный,
# line number 13: который на этой планете от её самого зарождения, ещё когда только Солнце
# line number 14: только-только сформировалось как звезда, и вот это газопылевое облако,
# line number 15: вот, после взрыва, Солнца, когда оно вспыхнуло, как звезда, начало
# line number 16: формировать вот эти коацерваты, планеты, понимаешь, я на этой Земле уже
# line number 17: как будто почти пять миллиардов лет живу и знаю её вдоль и поперёк
# line number 18: этот весь мир, а ты мне какие-то... мне не важно на твои тачки, на твои
# line number 19: яхты, на твои квартиры, там, на твоё благо.

# %%
with open("input.txt", "r") as f:
    for line in f:  # не делаем .readlines(), это сильно менее эффективно по памяти, будем хранить весь список строк :(
        if line.strip():
            print(f"yet another line: {line.strip()}")
# Out:
# yet another line: Я в своем познании настолько преисполнился, что я как будто бы уже
# yet another line: сто триллионов миллиардов лет проживаю на триллионах и
# yet another line: триллионах таких же планет, как эта Земля, мне этот мир абсолютно
# yet another line: понятен, и я здесь ищу только одного - покоя, умиротворения и
# yet another line: вот этой гармонии, от слияния с бесконечно вечным, от созерцания
# yet another line: великого фрактального подобия и от вот этого замечательного всеединства
# yet another line: существа, бесконечно вечного, куда ни посмотри, хоть вглубь - бесконечно
# yet another line: малое, хоть ввысь - бесконечное большое, понимаешь? А ты мне опять со
# yet another line: своим вот этим, иди суетись дальше, это твоё распределение, это
# yet another line: твой путь и твой горизонт познания и ощущения твоей природы, он
# yet another line: несоизмеримо мелок по сравнению с моим, понимаешь? Я как будто бы уже
# yet another line: давно глубокий старец, бессмертный, ну или там уже почти бессмертный,
# yet another line: который на этой планете от её самого зарождения, ещё когда только Солнце
# yet another line: только-только сформировалось как звезда, и вот это газопылевое облако,
# yet another line: вот, после взрыва, Солнца, когда оно вспыхнуло, как звезда, начало
# yet another line: формировать вот эти коацерваты, планеты, понимаешь, я на этой Земле уже
# yet another line: как будто почти пять миллиардов лет живу и знаю её вдоль и поперёк
# yet another line: этот весь мир, а ты мне какие-то... мне не важно на твои тачки, на твои
# yet another line: яхты, на твои квартиры, там, на твоё благо.

# %%
with open("output.txt", "w") as f:
    print("hello world!", file=f)  # самый обычный принт со всеми sep и end, только в файл

# %%
with open("output.txt", "a") as f:
    print("hello world!", file=f)  # самый обычный принт со всеми sep и end, только в файл

# %%
with open("output.txt", "w") as f:
    f.write("hello world\n")  # можно еще так, но write не переводит строку, поэтому надо на конце писать явно \n
    f.write("goodbye")

# %%
name = input()

# %%
import sys

print(sys.stdin.readlines())  # можно читать как из файла со стандартного потока вывода

# для PyCharm/VsCode и тд, чтобы закончить ввод, надо нажат ctrl + D
# для юпитера и колаба это не работает, плак плак

# for line in sys.stdin – так тоже
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 3
#       1 import sys
# ----> 3 print(sys.stdin.readlines())  # можно читать как из файла со стандартного потока вывода
#       5 # for line in sys.stdin – так тоже
#
# KeyboardInterrupt:

# %%
print("hello", file=sys.stdin)  # так нельзя, можно только читать
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 print("hello", file=sys.stdin)  # так нельзя, можно только читать
#
# UnsupportedOperation: not writable

# %%
import sys

sys.stdout.write("hello world")  # и писать на поток тоже, если есть необходимость
# Out:
# hello world
# 11

# %%
# ВАМ ЭТО НЕ НУЖНО

# 0 – stdin
# 1 – stdout
# 2 – stderr

import os

os.write(1, b'ababa')
# Out:
# ababa
# 5

# %% [markdown]
# ### Хотим: эффективно посчитать кол-во строк в файле

# %%
with open("input.txt", "r") as f:
    print(sum(1 for _ in f))
# Out:
# 19

# %%
with open("input.txt", "r") as f:
    count = 0
    for _ in f:
        count += 1
